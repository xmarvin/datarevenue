# %%
import pandas as pd
import numpy as np
#import seaborn as sns
#import matplotlib.pyplot as plt

#%matplotlib inline

# %%
df = pd.read_csv('/Users/marvin/testcases/datarevenue/data_root/raw/wine_dataset.csv')
df = df.drop(df.columns[0], axis=1)

# %%
df.describe()
# Out:
#              points        price
# count  10000.000000  9323.000000
# mean      88.460000    35.447603
# std        3.030003    40.898626
# min       80.000000     5.000000
# 25%       86.000000    17.000000
# 50%       88.000000    25.000000
# 75%       91.000000    42.000000
# max      100.000000  1300.000000

# %%
df.head(3)
# Out:
#   country                                        description  designation  \
# 0   Italy  Fragrances suggest hay, crushed tomato vine an...  Kirchleiten
# 1  France  Packed with fruit and crisp acidity, this is a...          NaN
# 2   Italy  This easy, ruby-red wine displays fresh berry ...          NaN
#
#    points  price            province          region_1 region_2  \
# 0      90   30.0  Northeastern Italy        Alto Adige      NaN
# 1      87   22.0        Loire Valley          Sancerre      NaN
# 2      86    NaN             Tuscany  Chianti Classico      NaN
#
#      taster_name taster_twitter_handle  \
# 0  Kerin O’Keefe          @kerinokeefe
# 1     Roger Voss            @vossroger
# 2            NaN                   NaN
#
#                                                title     variety  \
# 0  Tiefenbrunner 2012 Kirchleiten Sauvignon (Alto...   Sauvignon
# 1       Bernard Reverdy et Fils 2014 Rosé (Sancerre)        Rosé
# ...

# %%
df.groupby('country')['points'].mean()
# Out:
# country
# Argentina         86.524272
# Armenia           87.000000
# Australia         88.679012
# Austria           90.223048
# Brazil            88.000000
# Bulgaria          87.769231
# Canada            89.411765
# Chile             86.589888
# Croatia           87.857143
# Cyprus            85.000000
# Czech Republic    87.500000
# England           91.750000
# France            88.763552
# Georgia           85.666667
# Germany           90.024242
# Greece            87.647059
# Hungary           88.800000
# India             90.000000
# Israel            88.461538
# Italy             88.632363
# Lebanon           85.000000
# Macedonia         85.000000
# Mexico            84.833333
# Moldova           87.500000
# Morocco           89.000000
# New Zealand       88.692308
# Peru              83.000000
# Portugal          88.399527
# Romania           86.090909
# Serbia            87.500000
# Slovenia          88.000000
# South Africa      88.234783
# Spain             87.133333
# ...

# %%
df.isnull().describe()
# Out:
#        country description designation points  price province region_1  \
# count    10000       10000       10000  10000  10000    10000    10000
# unique       2           1           2      1      2        2        2
# top      False       False       False  False  False    False    False
# freq      9994       10000        7171  10000   9323     9994     8336
#
#        region_2 taster_name taster_twitter_handle  title variety winery  \
# count     10000       10000                 10000  10000   10000  10000
# unique        2           2                     2      1       1      1
# top        True       False                 False  False   False  False
# freq       6147        8015                  7644  10000   10000  10000
#
#        description_len title_len  group
# count            10000     10000  10000
# unique               1         1      1
# top              False     False  False
# freq             10000     10000  10000

# %%
df.loc[df['price'].isnull()].head(3)
# Out:
#    country                                        description designation  \
# 2    Italy  This easy, ruby-red wine displays fresh berry ...         NaN
# 8   France  Gold in color, this is a wine with notes of sp...         NaN
# 23  France  This is a deep-colored, ripe wine, with touche...         NaN
#
#     points  price  province            region_1 region_2 taster_name  \
# 2       86    NaN   Tuscany    Chianti Classico      NaN         NaN
# 8       94    NaN  Bordeaux           Sauternes      NaN  Roger Voss
# 23      87    NaN  Bordeaux  Bordeaux Supérieur      NaN  Roger Voss
#
#    taster_twitter_handle                                     title  \
# 2                    NaN            Dievole 2009  Chianti Classico
# 8             @vossroger  Château Lamothe Guignard 2009  Sauternes
# 23            @vossroger    Clos Monicord 2011  Bordeaux Supérieur
#
#                        variety                    winery  description_len  \
# ...

# %%
df['country'].unique()
# Out:
# array(['Italy', 'France', 'US', 'South Africa', 'Australia', 'Argentina',
#        'Germany', 'Austria', 'New Zealand', 'Chile', 'Spain', 'Portugal',
#        'Canada', 'Hungary', 'England', 'Slovenia', 'Israel', 'Bulgaria',
#        'Turkey', 'Romania', 'Mexico', 'Greece', 'Serbia', 'Uruguay', nan,
#        'Croatia', 'Lebanon', 'Georgia', 'Brazil', 'India', 'Moldova',
#        'Czech Republic', 'Switzerland', 'Peru', 'Morocco', 'Armenia',
#        'Macedonia', 'Cyprus'], dtype=object)

# %%
df['taster_twitter_handle'].nunique()
# Out:
# 14

# %%
df['province'].unique()
# Out:
# array(['Northeastern Italy', 'Loire Valley', 'Tuscany', 'California',
#        'New York', 'Bordeaux', 'Washington', 'Western Cape',
#        'Western Australia', 'Veneto', 'South Australia', 'Victoria',
#        'Mendoza Province', 'Other', 'Mittelrhein', 'Wachau', 'Tasmania',
#        "Hawke's Bay", 'Piedmont', 'Maule Valley', 'Languedoc-Roussillon',
#        'Overberg', 'Oregon', 'Central Valley', 'Northern Spain',
#        'Waiheke Island', 'Casablanca Valley', 'Lisboa', 'Catalonia',
#        'Robertson', 'Alsace', 'Burgenland', 'Champagne',
#        'Cachapoal Valley', 'Aconcagua Valley', 'France Other',
#        'Sicily & Sardinia', 'British Columbia', 'New Jersey', 'Tejo',
#        'Burgundy', 'Port', 'Chile', 'Galicia', 'Southern Italy',
#        'Colchagua Valley', 'Virginia', 'Provence', 'Douro',
#        'Central Italy', 'Mosel', 'Southwest France', 'Rheingau',
#        'Thermenregion', 'Lombardy', 'Franken', 'Alentejo',
# ...

# %%
df['description_len'] = df['description'].apply(len)

def points2group(score):
    splits = [85,90,95]
    for (index, split) in enumerate(splits):
        if score < split:
            return index
    return len(splits)
df['group'] = df['points'].apply(points2group)

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
ax.set_title('Grouped per points', fontweight="bold", size=25)
ax.set_ylabel('Number of wines')
ax.set_xlabel('Points')
df.groupby(['points']).count()['title'].plot(ax=ax, kind='bar')

# %%
sns.jointplot(x='price',y='points',data=df)

# %%
sns.jointplot(x='description_len',y='points',data=df, kind="reg")

# %%
sns.jointplot(x='price',y='group',data=df)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-8df131e207cb> in <module>()
# ----> 1 df['group'] = df['score'].apply(points2group)
#
# NameError: name 'df' is not defined
