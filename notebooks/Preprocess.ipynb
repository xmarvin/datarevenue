# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction import text
from nltk.tokenize import RegexpTokenizer
from nltk.stem.snowball import SnowballStemmer

# %matplotlib inline

# %%
df = pd.read_csv('/Users/marvin/testcases/datarevenue/data_root/raw/wine_dataset.csv')
df = df.drop(df.columns[0], axis=1)
df['country'] = df['country'].fillna('unk')
df['country'] = df['country'].astype('category')

# %%
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'[a-zA-Z\']+')
title_tokenizer = RegexpTokenizer(r'[a-zA-Z0-9\']+')
stop_words = text.ENGLISH_STOP_WORDS

def tokenize(text):
    return [stemmer.stem(word) for word in title_tokenizer.tokenize(text.lower()) if word not in stop_words]

# %%
vectorizer = TfidfVectorizer(tokenizer = tokenize, max_features = 1000, ngram_range=(1,2))
descriptions = df['description'].values
vectorizer.fit(descriptions)
description_encodings = vectorizer.transform(descriptions)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:1039: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
vectorizer.vocabulary_
# Out:
# {'pepper': 651,
#  'flavor wine': 373,
#  'rare': 712,
#  'bodi wine': 139,
#  'plump': 682,
#  'bacon': 83,
#  'grenach': 438,
#  'evolv': 327,
#  'purpl': 704,
#  'medium': 555,
#  'aroma flavor': 68,
#  'mourv dre': 583,
#  'easi drink': 309,
#  'bite': 110,
#  'silki textur': 799,
#  'classic': 212,
#  'green': 434,
#  'select': 788,
#  'warm': 939,
#  'standard': 841,
#  'ripe wine': 760,
#  'yeasti': 988,
#  '2019': 12,
#  'compon': 230,
#  'appl pear': 62,
#  'domin': 280,
#  'drink': 289,
#  'hazelnut': 447,
#  'dark berri': 251,
#  'plum flavor': 680,
#  'live acid': 534,
#  'lead': 505,
#  'red currant': 726,
#  'point': 685,
#  'delici': 262,
#  'bottl': 144,
#  'produc': 696,
#  'true': 913,
#  'new oak': 600,
#  'product': 697,
#  'good acid': 421,
#  'petit': 659,
#  'rich fruit': 746,
#  'chocol': 203,
#  'charm': 188,
#  'viognier': 934,
#  'palat show': 641,
#  'work': 981,
#  'polish tannin': 687,
#  'deepli': 258,
#  'cherri plum': 199,
#  'sparkl': 829,
#  'headi': 448,
#  'meyer lemon': 565,
#  'ginger': 413,
#  'appl': 59,
#  'shape': 792,
#  'shine': 794,
#  'extra': 335,
#  'pepperi': 652,
#  'fresh acid': 391,
#  'rich': 745,
#  'structur': 855,
#  'influenc': 475,
#  'rubber': 770,
#  'delic': 261,
#  'combin': 225,
#  'till': 899,
#  'flower': 377,
#  'zinfandel': 999,
#  'remain': 736,
#  'drink 2020': 295,
#  'acid wine': 36,
#  'balanc acid': 87,
#  'cherri flavor': 196,
#  'wine need': 966,
#  'brisk': 155,
#  'appeal': 55,
#  'red cherri': 725,
#  'burst': 162,
#  'singl vineyard': 802,
#  'smooth': 815,
#  'concentr wine': 232,
#  'mellow': 559,
#  'easygo': 310,
#  'slate': 807,
#  '2010': 6,
#  'tang': 873,
#  'blossom': 132,
#  'pie': 662,
#  'vanilla flavor': 923,
#  'blueberri': 135,
#  'rose petal': 767,
#  'tough': 909,
#  'gritti': 442,
#  'blend cabernet': 131,
#  'chardonnay': 187,
#  'lush': 542,
#  'play': 672,
#  'leav': 512,
#  'coat': 218,
#  'fair': 340,
#  'tangerin': 874,
#  'rh ne': 743,
#  'complet': 228,
#  'merlot cabernet': 563,
#  'citrus': 208,
#  'dri': 283,
#  'butteri': 165,
#  'black': 112,
#  'spring': 835,
#  'honey': 466,
#  'get': 412,
#  'smoki oak': 814,
#  'currant flavor': 247,
#  'boast': 136,
#  'ferment': 346,
#  'dusti tannin': 304,
#  'keep': 496,
#  'graphit': 430,
#  'bordeaux': 143,
#  'aftertast': 40,
#  'minti': 574,
#  'base': 93,
#  'near': 592,
#  'black fruit': 115,
#  'petal': 658,
#  'entic': 318,
#  'line': 528,
#  'generous': 410,
#  'site': 805,
#  'dri black': 284,
#  'star anis': 843,
#  'butterscotch': 166,
#  '2015': 8,
#  'steeli': 847,
#  'ne': 591,
#  's': 774,
#  'bright acid': 151,
#  'chalki': 182,
#  'age': 41,
#  'aroma come': 67,
#  'add': 38,
#  'featur': 343,
#  'core': 237,
#  'dole': 279,
#  'readi drink': 718,
#  'medicin': 554,
#  'lime': 527,
#  'nutmeg': 610,
#  'present': 691,
#  'improv': 473,
#  'satisfi': 781,
#  'aroma palat': 70,
#  'edg': 311,
#  'acid': 30,
#  'lead nose': 506,
#  'mean': 551,
#  'herbal': 455,
#  'known': 497,
#  'meet': 558,
#  'ampl': 51,
#  'velveti tannin': 927,
#  'tannic': 876,
#  '30': 19,
#  'juici': 490,
#  'blue flower': 134,
#  'readi': 717,
#  'cab': 167,
#  'dri finish': 285,
#  'like': 526,
#  'white fruit': 948,
#  'tempranillo': 889,
#  'grace': 425,
#  'drink 2019': 294,
#  'background': 82,
#  'lee': 513,
#  'driven': 300,
#  'strong': 854,
#  '2016': 9,
#  'pepperi spice': 653,
#  'mourv': 582,
#  'need time': 596,
#  'high tone': 460,
#  'lemon zest': 516,
#  'midpal': 566,
#  'surpris': 867,
#  'consist': 233,
#  'evid': 326,
#  'fruit': 395,
#  'focus': 378,
#  'tannin acid': 878,
#  'young wine': 994,
#  'pleas': 673,
#  'acid flavor': 34,
#  'level': 520,
#  'highlight': 461,
#  'creami textur': 241,
#  'open aroma': 624,
#  'robust': 763,
#  'take': 872,
#  'fine': 350,
#  'inki': 477,
#  'grass': 431,
#  'textur': 891,
#  'aroma suggest': 73,
#  'rich wine': 748,
#  'assert': 76,
#  'bake': 84,
#  'rang': 711,
#  'white flower': 947,
#  'dish': 274,
#  'wild berri': 954,
#  'napa': 589,
#  'juic': 489,
#  'stalki': 839,
#  'cherri black': 192,
#  'finish it': 357,
#  'cassi': 177,
#  'linger': 530,
#  'white': 946,
#  'clone': 215,
#  'defin': 259,
#  'close': 216,
#  'lace': 499,
#  'black raspberri': 119,
#  'tangi': 875,
#  'berri aroma': 102,
#  'make wine': 545,
#  'noir': 602,
#  'dri wine': 288,
#  'young': 993,
#  'o': 612,
#  'backbon': 81,
#  'make': 544,
#  'oili': 619,
#  'cabernet': 168,
#  'black plum': 118,
#  'peach flavor': 646,
#  'lift': 522,
#  'everyday': 325,
#  'dessert': 270,
#  'rough': 768,
#  'peel': 649,
#  'end': 316,
#  'love': 539,
#  'balsam': 89,
#  'chunki': 206,
#  'mix': 575,
#  'crisp': 243,
#  'quit': 708,
#  'match': 549,
#  'toast': 902,
#  'ripe red': 759,
#  'friend': 394,
#  'tannin drink': 879,
#  'pinot noir': 668,
#  '20': 5,
#  'last': 501,
#  'perfect': 654,
#  'year': 985,
#  'citrusi': 211,
#  'addit': 39,
#  'variet': 924,
#  'drink 2022': 296,
#  'appl flavor': 61,
#  'fruit spice': 403,
#  'nice': 601,
#  'earth': 306,
#  'straightforward': 851,
#  'ap': 53,
#  'green herb': 437,
#  'pithi': 670,
#  'cherri blackberri': 193,
#  'oaki': 615,
#  'mouthwat': 587,
#  'differ': 272,
#  'orchard fruit': 630,
#  'sharp': 793,
#  'toasti': 904,
#  'yeast': 987,
#  'region': 733,
#  'solid': 821,
#  'dark chocol': 253,
#  "doesn't": 278,
#  'champagn': 183,
#  'drink 2016': 291,
#  'appel': 57,
#  '100': 1,
#  'red wine': 729,
#  'honeysuckl': 468,
#  'follow': 379,
#  'ripe': 752,
#  'profil': 698,
#  'cocoa': 219,
#  'burnt': 161,
#  'flavor cherri': 366,
#  'mingl': 572,
#  'relat': 734,
#  'medium weight': 557,
#  'wine soft': 973,
#  'light bodi': 524,
#  'price': 695,
#  'run': 772,
#  'given': 416,
#  'pinot': 667,
#  'fruiti wine': 406,
#  'slight': 808,
#  'ripe fruiti': 757,
#  'eucalyptus': 324,
#  'purpl flower': 705,
#  'crisp acid': 244,
#  'flavor ripe': 372,
#  'color': 223,
#  'dri tannin': 287,
#  'nose': 603,
#  'butter toast': 164,
#  'finish dri': 355,
#  'fill': 348,
#  'vanilla': 922,
#  'clean': 213,
#  'moder': 577,
#  'berri flavor': 104,
#  'fresh': 390,
#  'menthol': 561,
#  'almond': 49,
#  'blackberri jam': 128,
#  'plus': 683,
#  'balanc': 86,
#  'blackberri': 121,
#  'polish': 686,
#  'raspberri': 713,
#  'sauc': 782,
#  '60': 25,
#  'set': 791,
#  'textur wine': 892,
#  'pomegran': 688,
#  '40': 21,
#  'approach': 63,
#  'sparkler': 830,
#  'verdot': 928,
#  'pineappl': 664,
#  'gorgeous': 423,
#  'wine come': 958,
#  'pear flavor': 648,
#  'wood age': 979,
#  'red fruit': 727,
#  'floor': 375,
#  'coffe': 221,
#  'bone': 141,
#  'drink soon': 297,
#  'miner': 570,
#  'drink 2015': 290,
#  'turn': 914,
#  'chewi': 202,
#  'drink 2017': 292,
#  'cake': 171,
#  'ripe blackberri': 755,
#  'firm': 359,
#  'mocha': 576,
#  'dri herb': 286,
#  'person': 657,
#  'vibrant': 929,
#  'wait': 937,
#  'wine drink': 960,
#  'herb': 453,
#  'grippi': 441,
#  'mouth': 585,
#  'depth': 267,
#  'unfold': 917,
#  'concentr': 231,
#  'simpl': 800,
#  'perfum': 655,
#  'tar': 883,
#  'month': 580,
#  'green fruit': 436,
#  'brood': 158,
#  '2017': 10,
#  'high alcohol': 459,
#  'decad': 255,
#  'wine': 956,
#  'tri': 910,
#  'spici': 834,
#  'organ': 631,
#  'wild': 953,
#  'underbrush': 916,
#  'milk chocol': 569,
#  'fennel': 345,
#  'express': 334,
#  'style': 857,
#  'form': 383,
#  'acid finish': 33,
#  'flavor finish': 368,
#  '10': 0,
#  'natur': 590,
#  '12': 2,
#  'famili': 341,
#  'bodi palat': 138,
#  'earthi': 307,
#  'stainless': 837,
#  'yellow': 989,
#  'thyme': 896,
#  'wine good': 962,
#  'linear': 529,
#  'blue': 133,
#  'raspberri cherri': 714,
#  'passion': 643,
#  'bright': 150,
#  'high': 457,
#  'bit': 109,
#  'right': 750,
#  'note': 607,
#  'soft tannin': 818,
#  'rh': 742,
#  'hold': 465,
#  'peach': 645,
#  'fruit aroma': 397,
#  'itali': 486,
#  'littl': 532,
#  'hit': 464,
#  'e': 305,
#  'show': 797,
#  'age year': 44,
#  'new': 598,
#  'despit': 269,
#  'cook': 235,
#  'black pepper': 117,
#  'taut': 887,
#  'rhubarb': 744,
#  'pure': 703,
#  'drinkabl': 299,
#  '4': 20,
#  'wine great': 963,
#  'includ': 474,
#  'pencil': 650,
#  'prune': 702,
#  'bean': 96,
#  '2020': 13,
#  'provid': 701,
#  'balanc wine': 88,
#  'apricot': 64,
#  'asian': 75,
#  '8': 26,
#  'steel': 846,
#  'linger finish': 531,
#  'structur wine': 856,
#  'bread': 149,
#  'doe': 277,
#  'pale': 642,
#  'zest': 996,
#  'cola': 222,
#  'forest floor': 382,
#  'vine': 931,
#  'entri': 320,
#  'generic': 409,
#  'creami': 240,
#  'live': 533,
#  'berri fruit': 105,
#  'flavor': 363,
#  'there': 894,
#  'it rich': 485,
#  'refresh': 732,
#  'forward': 384,
#  'wine light': 965,
#  'chees': 189,
#  'subdu': 858,
#  'malbec': 546,
#  'intrigu': 481,
#  'thing': 895,
#  'salt': 777,
#  'orang': 626,
#  'nose wine': 606,
#  'overal': 632,
#  'short': 796,
#  'load': 535,
#  'wild cherri': 955,
#  'leather': 510,
#  'cabernet franc': 169,
#  'estat': 323,
#  'cherri licoric': 198,
#  'banana': 90,
#  'best': 106,
#  'plush': 684,
#  'intens': 479,
#  'pretti': 694,
#  'grill': 439,
#  'crush': 245,
#  'syrupi': 871,
#  'pink grapefruit': 666,
#  'blackberri cassi': 123,
#  'decant': 256,
#  'acid balanc': 31,
#  'cellar': 179,
#  '2021': 14,
#  'chocolati': 204,
#  'tannin finish': 880,
#  'mouss': 584,
#  'wonder': 977,
#  'mouthfeel': 586,
#  'fat': 342,
#  'realli': 720,
#  'tropic fruit': 912,
#  'lot': 538,
#  'fruit palat': 401,
#  'mountain': 581,
#  'hot': 469,
#  'basic': 94,
#  'oliv': 622,
#  'screwcap': 787,
#  'fade': 339,
#  'summer': 864,
#  'palat flavor': 639,
#  'world': 982,
#  'flavor blackberri': 365,
#  'continu': 234,
#  'lavend': 503,
#  'jammi': 488,
#  'juici acid': 491,
#  'merlot': 562,
#  'salti': 778,
#  'sangioves': 780,
#  'shiraz': 795,
#  'luscious': 541,
#  'sophist': 824,
#  'tight': 897,
#  'tobacco': 905,
#  'tast': 885,
#  'berri cherri': 103,
#  'offer aroma': 617,
#  'spice': 831,
#  'meat': 552,
#  'give wine': 415,
#  'carri': 175,
#  'acid it': 35,
#  'citrus flavor': 209,
#  'bitter': 111,
#  'allow': 47,
#  'raspberri flavor': 715,
#  'give': 414,
#  'rock': 764,
#  'ad': 37,
#  'tannin': 877,
#  'overrip': 633,
#  'smell': 811,
#  'oak flavor': 614,
#  'fleshi': 374,
#  'green appl': 435,
#  'leafi': 508,
#  'pleasur': 675,
#  'bold': 140,
#  'tropic': 911,
#  'finish': 354,
#  'lyche': 543,
#  'raisin': 710,
#  'except': 330,
#  'grabbi': 424,
#  'wine rich': 970,
#  'touch': 908,
#  'benefit': 100,
#  'fragrant': 385,
#  'blackberri black': 122,
#  'golden': 419,
#  'skin': 806,
#  'varieti': 925,
#  'cinnamon': 207,
#  'it dri': 484,
#  'flavor raspberri': 371,
#  'dusti': 303,
#  'fig': 347,
#  'pear': 647,
#  'salin': 776,
#  'easi': 308,
#  'nose bottl': 604,
#  'old': 620,
#  'densiti': 266,
#  'dark': 250,
#  'grown': 444,
#  'red berri': 724,
#  'berri': 101,
#  'wine show': 972,
#  'nectarin': 593,
#  'pith': 669,
#  'real': 719,
#  'effort': 312,
#  'case': 176,
#  'franc': 387,
#  '2025': 16,
#  'southern': 828,
#  'white wine': 951,
#  'reserv': 737,
#  'just': 494,
#  'wine offer': 967,
#  'finish long': 358,
#  'press': 693,
#  'dark fruit': 254,
#  'wine fresh': 961,
#  'flavor black': 364,
#  'long': 536,
#  'winemak': 975,
#  'black oliv': 116,
#  'char': 184,
#  'big': 108,
#  'stew': 848,
#  'succul': 860,
#  'creat': 242,
#  'astring': 77,
#  'heavi': 451,
#  'fine tannin': 352,
#  'black currant': 114,
#  'sour cherri': 826,
#  'orang zest': 628,
#  'accent': 27,
#  '25': 17,
#  'attract': 78,
#  'cream': 239,
#  'steak': 845,
#  'neutral': 597,
#  'brown': 159,
#  "don't": 281,
#  'spice flavor': 833,
#  'high acid': 458,
#  'age wine': 43,
#  'age drink': 42,
#  'hill': 462,
#  '15': 3,
#  'stone': 849,
#  'wood': 978,
#  '3': 18,
#  'soil': 820,
#  'enjoy': 317,
#  'promis': 700,
#  'brisk acid': 156,
#  '2018': 11,
#  'subtl': 859,
#  'that': 893,
#  'it': 483,
#  'bay': 95,
#  'jam': 487,
#  'go': 418,
#  'zesti': 997,
#  'import': 471,
#  'initi': 476,
#  'valley': 920,
#  'open': 623,
#  'youth': 995,
#  'need age': 595,
#  'aroma ripe': 72,
#  'cherri cola': 194,
#  'fruit wine': 404,
#  'hint': 463,
#  'plenti': 676,
#  'red appl': 723,
#  'grassi': 432,
#  'plant': 671,
#  'velveti': 926,
#  'grain tannin': 427,
#  'recal': 721,
#  'rose': 766,
#  'dark cherri': 252,
#  'plum fruit': 681,
#  'barrel': 91,
#  'emerg': 315,
#  'develop': 271,
#  'fresh fruit': 392,
#  'ripe fruit': 756,
#  'mango': 547,
#  'currant': 246,
#  'fruit acid': 396,
#  'aromat': 74,
#  'meyer': 564,
#  'length': 519,
#  'bake spice': 85,
#  'brambl': 148,
#  'oak': 613,
#  'syrup': 870,
#  'bodi': 137,
#  'heat': 450,
#  'strawberri': 852,
#  'complex': 229,
#  'hearti': 449,
#  'palat offer': 640,
#  'butter': 163,
#  'currant fruit': 248,
#  'modest': 579,
#  'grapefruit': 429,
#  'just right': 495,
#  'firm tannin': 361,
#  'exuber': 338,
#  'sweet': 868,
#  'wine it': 964,
#  'excel': 329,
#  '6': 24,
#  'sour': 825,
#  'wine age': 957,
#  'aroma': 65,
#  'warmth': 940,
#  'mark': 548,
#  'wave': 941,
#  'smoki': 813,
#  'distinct': 276,
#  'grain': 426,
#  'frame': 386,
#  'exot spice': 332,
#  'extrem': 337,
#  'long finish': 537,
#  'dens': 265,
#  'pleasant': 674,
#  'matur': 550,
#  'finess': 353,
#  'quick': 707,
#  'lemoni': 517,
#  'allur': 48,
#  'nut': 609,
#  'brighten': 152,
#  'citrus fruit': 210,
#  'ripe berri': 753,
#  'firm structur': 360,
#  'reflect': 731,
#  'new french': 599,
#  'california': 172,
#  'rubberi': 771,
#  'expect': 333,
#  'offer': 616,
#  'oil': 618,
#  'leaf': 507,
#  'support': 866,
#  'suppl': 865,
#  'promin': 699,
#  'stainless steel': 838,
#  'spice aroma': 832,
#  'time': 900,
#  'violet': 935,
#  'tea': 888,
#  'beef': 98,
#  'blanc': 129,
#  'meati': 553,
#  '2022': 15,
#  'plum berri': 678,
#  'wineri': 976,
#  'lack': 500,
#  'drink wine': 298,
#  'soften': 819,
#  'cherri currant': 195,
#  'persist': 656,
#  'tannin provid': 882,
#  'integr': 478,
#  'passion fruit': 644,
#  'flavor light': 370,
#  'lighter': 525,
#  'ap ritif': 54,
#  'wrap': 984,
#  'bone dri': 142,
#  'aroma red': 71,
#  'sandalwood': 779,
#  'tone': 907,
#  'plum cherri': 679,
#  'caramel': 174,
#  'good': 420,
#  'leatheri': 511,
#  'invit': 482,
#  'somewhat': 822,
#  'wet': 944,
#  'exampl': 328,
#  'smoke': 812,
#  'fresh fruiti': 393,
#  'stage': 836,
#  'juici fruit': 493,
#  'modern': 578,
#  'clove': 217,
#  'herbac': 454,
#  'pack': 634,
#  'lend': 518,
#  'appl citrus': 60,
#  'wine dri': 959,
#  'mushroom': 588,
#  'wide': 952,
#  'cherri berri': 191,
#  "you'll": 992,
#  'orchard': 629,
#  'certain': 181,
#  'ros': 765,
#  'begin': 99,
#  'drop': 301,
#  'vintag': 933,
#  'sauvignon blanc': 784,
#  'sirah': 804,
#  'want': 938,
#  'lemon lime': 515,
#  'interest': 480,
#  'hard': 445,
#  'ting': 901,
#  'scent': 786,
#  'qualiti': 706,
#  'unusu': 918,
#  'black cherri': 113,
#  'deep': 257,
#  'drink 2018': 293,
#  'lemon': 514,
#  '2014': 7,
#  'plum': 677,
#  'dryness': 302,
#  'year old': 986,
#  'old vine': 621,
#  'back': 80,
#  'residu': 738,
#  'charact': 185,
#  'chop': 205,
#  'fulli': 407,
#  'vibrant acid': 930,
#  'toast oak': 903,
#  'design': 268,
#  'medium bodi': 556,
#  'roast': 762,
#  'pine': 663,
#  'broad': 157,
#  'aroma black': 66,
#  'food': 380,
#  'fruiti': 405,
#  'final': 349,
#  'valu': 921,
#  'game': 408,
#  'releas': 735,
#  'mint': 573,
#  'late': 502,
#  'display': 275,
#  'power': 690,
#  'delight': 263,
#  'term': 890,
#  'brace': 147,
#  'harmoni': 446,
#  'red': 722,
#  'immedi': 470,
#  'direct': 273,
#  'soon': 823,
#  '5': 22,
#  'candi': 173,
#  'savori': 785,
#  'tannin it': 881,
#  'mild': 567,
#  'fruit rich': 402,
#  'cabernet sauvignon': 170,
#  'white peach': 949,
#  'rustic': 773,
#  'licoric': 521,
#  'coconut': 220,
#  'potenti': 689,
#  'sourc': 827,
#  'fine grain': 351,
#  'tomato': 906,
#  'flavor it': 369,
#  'tight wound': 898,
#  'suggest': 863,
#  'smooth tannin': 816,
#  'black tea': 120,
#  'start': 844,
#  'petit verdot': 661,
#  'refin': 730,
#  'blackberri fruit': 127,
#  'light': 523,
#  'grape': 428,
#  'here': 456,
#  'petit sirah': 660,
#  'anis': 52,
#  'climat': 214,
#  'need': 594,
#  'better': 107,
#  'extract': 336,
#  'entir': 319,
#  'reveal': 741,
#  'zin': 998,
#  'forest': 381,
#  'opul': 625,
#  'stone fruit': 850,
#  'bubbl': 160,
#  'low': 540,
#  'melon': 560,
#  'label': 498,
#  'cherri': 190,
#  'fruit finish': 398,
#  '2': 4,
#  'cut': 249,
#  'lean': 509,
#  'blackberri currant': 125,
#  'auster': 79,
#  'whiff': 945,
#  'espresso': 322,
#  'bouquet': 145,
#  'streak': 853,
#  'cranberri': 238,
#  'blackberri cherri': 124,
#  'way': 942,
#  'wine open': 968,
#  'feel': 344,
#  'rich textur': 747,
#  'palat deliv': 637,
#  'aroma lead': 69,
#  'pair': 635,
#  'wine that': 974,
#  'yellow appl': 990,
#  'access': 28,
#  'singl': 801,
#  'sugari': 862,
#  'layer': 504,
#  'brini': 154,
#  'round': 769,
#  'honeydew': 467,
#  'deliv': 264,
#  'air': 45,
#  'appear': 56,
#  'ritif': 761,
#  'yellow fruit': 991,
#  'sage': 775,
#  'barrel ferment': 92,
#  'stand': 840,
#  'french oak': 389,
#  'equal': 321,
#  'dre': 282,
#  'cool': 236,
#  'come': 226,
#  'eleg': 313,
#  'impress': 472,
#  'cedar': 178,
#  'raw': 716,
#  'flavor drink': 367,
#  'woodi': 980,
#  'result': 740,
#  'small': 810,
#  'typic': 915,
#  'white pepper': 950,
#  'tart': 884,
#  'sauvignon': 783,
#  'sugar': 861,
#  'center': 180,
#  'flat': 362,
#  'vineyard': 932,
#  'pink': 665,
#  'vivid': 936,
#  'boysenberri': 146,
#  'use': 919,
#  'great': 433,
#  'alcohol': 46,
#  'sensat': 790,
#  'weight': 943,
#  'sip': 803,
#  'blend': 130,
#  'ripe black': 754,
#  'orang peel': 627,
#  'gooseberri': 422,
#  'tasti': 886,
#  'ripe pear': 758,
#  'fruit flavor': 399,
#  'definit': 260,
#  'syrah': 869,
#  'raci': 709,
#  'nuanc': 608,
#  'grip': 440,
#  'preserv': 692,
#  'nutti': 611,
#  'fruit it': 400,
#  'alongsid': 50,
#  'floral': 376,
#  'sens': 789,
#  'exot': 331,
#  'cherri red': 201,
#  'glass': 417,
#  'palat dole': 638,
#  'beauti': 97,
#  'acid drink': 32,
#  'finish drink': 356,
#  'wine ripe': 971,
#  'milk': 568,
#  'element': 314,
#  '50': 23,
#  'nose palat': 605,
#  'ground': 443,
#  'french': 388,
#  'accompani': 29,
#  'cherri fruit': 197,
#  'characterist': 186,
#  'cherri raspberri': 200,
#  'wound': 983,
#  'restrain': 739,
#  'blackberri flavor': 126,
#  'color wine': 224,
#  'miner note': 571,
#  'slowli': 809,
#  'juici black': 492,
#  'riesl': 749,
#  'soft': 817,
#  'help': 452,
#  'rind': 751,
#  'compact': 227,
#  'red plum': 728,
#  'bring': 153,
#  'palat': 636,
#  'silki': 798,
#  'star': 842,
#  'wine readi': 969,
#  'gentl': 411,
#  'appet': 58}

# %%
((df['description'] + " " + df['title']) ).values
# Out:
# array(["Fragrances suggest hay, crushed tomato vine and exotic fruit. The bright but structured palate delivers peach, papaya, cantaloupe and energizing mineral notes alongside fresh acidity. It's nicely balanced with good length, Tiefenbrunner 2012 Kirchleiten Sauvignon (Alto Adige)",
#        'Packed with fruit and crisp acidity, this is a bright, light and perfumed wine. Red-berry flavors are lifted by red currants and a light spice. Drink now for total freshness. Bernard Reverdy et Fils 2014 Rosé (Sancerre)',
#        'This easy, ruby-red wine displays fresh berry flavors and a light, crisp mouthfeel. Pair this no-fuss wine with homemade pasta sauce or potato gnocchi and cheese. Dievole 2009  Chianti Classico',
#        ...,
#        'This perfumed, herbal blend of Syrah and Grenache is tight and very crisp. It has intense tangy acidity and a lively fruity aftertaste. This is a bone-dry rosé with a desire for food. Château Roquefeuille 2016 Rosé in the Air Rosé (Côtes de Provence)',
#        "Berry candy and licorice aromas become more subtle and earthy with air. It feels grabby and abrasive as many Toro's are prone to be, with blackberry and root notes and a sugar beet flavor. The slightly hot, candied finish holds onto that rooty character. Monte Hiniesta 2009  Toro",
#        "This blend of 70% Grenache, 25% Shiraz and 5% Mourvèdre features surprisingly dark fruit flavors akin to blackberries and cola. A hint of mint or eucalyptus enlivens the bouquet and helps to lighten this otherwise rather full-bodied, brooding wine. Finishes long, with enough dusty tannins to warrant cellaring through 2015. D'Arenberg 2005 The Ironstone Pressings G-S-M (McLaren Vale)"],
#       dtype=object)

# %%
description_encodings.shape
# Out:
# (10000, 1000)

# %%
tokenize(df['description'][0])
# Out:
# ['fragranc',
#  'suggest',
#  'hay',
#  'crush',
#  'tomato',
#  'vine',
#  'exot',
#  'fruit',
#  'bright',
#  'structur',
#  'palat',
#  'deliv',
#  'peach',
#  'papaya',
#  'cantaloup',
#  'energ',
#  'miner',
#  'note',
#  'alongsid',
#  'fresh',
#  'acid',
#  'it',
#  'nice',
#  'balanc',
#  'good',
#  'length']

# %%
df.head()
# Out:
#   country                                        description  \
# 0   Italy  Fragrances suggest hay, crushed tomato vine an...
# 1  France  Packed with fruit and crisp acidity, this is a...
# 2   Italy  This easy, ruby-red wine displays fresh berry ...
# 3      US  Pretty in violet and rose petals this is a low...
# 4      US  This golden wine confounds in a mix of wet sto...
#
#                designation  points  price            province  \
# 0              Kirchleiten      90   30.0  Northeastern Italy
# 1                      NaN      87   22.0        Loire Valley
# 2                      NaN      86    NaN             Tuscany
# 3  Horseshoe Bend Vineyard      92   50.0          California
# 4             Dutton Ranch      93   38.0          California
#
#                region_1 region_2     taster_name taster_twitter_handle  \
# 0            Alto Adige      NaN   Kerin O’Keefe          @kerinokeefe
# 1              Sancerre      NaN      Roger Voss            @vossroger
# 2      Chianti Classico      NaN             NaN                   NaN
# 3  Russian River Valley   Sonoma  Virginie Boone               @vboone
# 4  Russian River Valley   Sonoma  Virginie Boone               @vboone
#
#                                                title     variety  \
# 0  Tiefenbrunner 2012 Kirchleiten Sauvignon (Alto...   Sauvignon
# 1       Bernard Reverdy et Fils 2014 Rosé (Sancerre)        Rosé
# 2                     Dievole 2009  Chianti Classico  Sangiovese
# 3  Davis Family 2012 Horseshoe Bend Vineyard Pino...  Pinot Noir
# 4  Dutton-Goldfield 2013 Dutton Ranch Chardonnay ...  Chardonnay
#
#                     winery
# 0            Tiefenbrunner
# 1  Bernard Reverdy et Fils
# 2                  Dievole
# 3             Davis Family
# 4         Dutton-Goldfield

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
# country                  10000 non-null category
# description              10000 non-null object
# designation              7171 non-null object
# points                   10000 non-null int64
# price                    9323 non-null float64
# province                 9994 non-null object
# region_1                 8336 non-null object
# region_2                 3853 non-null object
# taster_name              8015 non-null object
# taster_twitter_handle    7644 non-null object
# title                    10000 non-null object
# variety                  10000 non-null object
# winery                   10000 non-null object
# dtypes: category(1), float64(1), int64(1), object(10)
# memory usage: 947.6+ KB

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(df['description'])
X = vectorizer.transform(df['description'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/feature_extraction/text.py:1039: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   if hasattr(X, 'dtype') and np.issubdtype(X.dtype, np.float):

# %%
X.shape
# Out:
# (10000, 11804)

# %%
enc = OneHotEncoder(handle_unknown='ignore')

# %%
enc.fit(df['country'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-342181502d7d> in <module>()
# ----> 1 enc.fit(df['country'])
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/data.py in fit(self, X, y)
#    1832         self
#    1833         """
# -> 1834         self.fit_transform(X)
#    1835         return self
#    1836
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/data.py in fit_transform(self, X, y)
#    1890         """
#    1891         return _transform_selected(X, self._fit_transform,
# -> 1892                                    self.categorical_features, copy=True)
#    1893
#    1894     def _transform(self, X):
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/preprocessing/data.py in _transform_selected(X, transform, selected, copy)
#    1695     X : array or sparse matrix, shape=(n_samples, n_features_new)
#    1696     """
# -> 1697     X = check_array(X, accept_sparse='csc', copy=copy, dtype=FLOAT_DTYPES)
#    1698
#    1699     if isinstance(selected, six.string_types) and selected == "all":
#
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     380                                       force_all_finite)
#     381     else:
# --> 382         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     383
#     384         if ensure_2d:
#
# ValueError: could not convert string to float: 'Australia'

# %%
country_encodings = pd.get_dummies(df['country'], prefix = 'country')

# %%
df = pd.concat([df, dfDummies], axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-df1048e34830> in <module>()
# ----> 1 df = pd.concat([df, dfDummies], axis=1)
#
# NameError: name 'dfDummies' is not defined

# %%
train_small_with_dummies = pd.get_dummies(train_small, sparse=True)
